# %% [markdown]
# https://cloud.cerebras.ai/

# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)

import os
os.environ["http_proxy"] = "http://127.0.0.1:22082"
os.environ["https_proxy"] = "http://127.0.0.1:22082"

model="gpt-oss-120b"

# %%
import requests
import os
import json

# 设置API密钥
api_key = os.getenv('CEREBRAS_API_KEY')  # 从环境变量获取
# 或者直接设置: api_key = "your_api_key_here"

# 请求头
headers = {
    'Content-Type': 'application/json',
    'Authorization': f'Bearer {api_key}'
}

# 请求体
data = {
    "model": "gpt-oss-120b",
    "stream": True,
    "max_tokens": 65536,
    "temperature": 1,
    "top_p": 1,
    "messages": [
        {
            "role": "system",
            "content": ""
        }
    ]
}

# 发送请求
url = 'https://api.cerebras.ai/v1/chat/completions'
response = requests.post(url, headers=headers, json=data, stream=True)

# 处理响应
if response.status_code == 200:
    if data.get('stream'):
        # 处理流式响应
        for line in response.iter_lines():
            if line:
                decoded_line = line.decode('utf-8')
                if decoded_line.startswith('data: '):
                    chunk_data = decoded_line[6:]  # 移除 'data: ' 前缀
                    if chunk_data.strip() == '[DONE]':
                        break
                    try:
                        chunk_json = json.loads(chunk_data)
                        # 处理每个数据块
                        print(chunk_json)
                    except json.JSONDecodeError:
                        continue
    else:
        # 处理非流式响应
        result = response.json()
        print(result)
else:
    print(f"请求失败: {response.status_code}")
    print(response.text)
# Out:
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'role': 'assistant'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': 'The'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' system'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' is'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' Chat'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': 'GPT'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': '.'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' The'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' user'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' says'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' "'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': 'You'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' are'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' Chat'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': 'GPT'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': '".'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' Then'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' provides'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' system'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' messages'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ','}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' including'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' that'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' I'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' must'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' respond'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' accordingly'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': '.'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' The'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' developer'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' message'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' is'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' empty'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ':'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' "#'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' Instructions'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': '".'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' Lik'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': 'ely'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' no'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' special'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' instruction'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ','}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' so'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' default'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' behaviour'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ':'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' answer'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' normally'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': '.'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': " There's"}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' no'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' user'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' query'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' yet'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': '.'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' The'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' next'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' user'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' turn'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' is'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' likely'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' to'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' ask'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' a'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' question'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': '.'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' I'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' need'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' to'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' be'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': ' ready'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'reasoning': '.'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'content': 'Ready'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'content': ' to'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'content': ' help'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'content': '!'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'content': ' Feel'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'content': ' free'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'content': ' to'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'content': ' ask'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'content': ' any'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'content': ' question'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'content': ' or'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'content': ' let'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'content': ' me'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'content': ' know'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'content': ' what'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'content': ' you'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'content': ' need'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'content': ' assistance'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'content': ' with'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {'content': '.'}, 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk'}
# {'id': 'chatcmpl-d7f1f404-7adf-43ca-abda-c14e7d164029', 'choices': [{'delta': {}, 'finish_reason': 'stop', 'index': 0}], 'created': 1754416114, 'model': 'gpt-oss-120b', 'system_fingerprint': 'fp_46eb986fb88f843657d6', 'object': 'chat.completion.chunk', 'usage': {'prompt_tokens': 70, 'completion_tokens': 102, 'total_tokens': 172, 'prompt_tokens_details': {'cached_tokens': 0}}, 'time_info': {'queue_time': 0.000354962, 'prompt_time': 0.003769112, 'completion_time': 0.099779426, 'total_time': 0.1053013801574707, 'created': 1754416114}}
